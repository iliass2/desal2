# %% [markdown]
# # 02 — Exploration de l’agressivité chimique
#
# ## Objectif
#
# Ce notebook explore les feuilles `MHLATHUZE` et `LUVUVU`, vérifie les variables communes, calcule l’indice de Larson avec conversion des concentrations en meq/L et construit la cible binaire `Larson_corrosive`.
#
# > **Point scientifique central :** la cible Larson dépend directement de `Cl`, `SO4` et `HCO3`. Cette dépendance sera explicitement prise en compte dans le notebook de modélisation afin d’éviter de surinterpréter les performances.

# %% [markdown]
# ## 1. Configuration

# %%
from pathlib import Path
import sys
import warnings

warnings.filterwarnings("ignore")

PROJECT_ROOT = (
    Path.cwd().resolve().parent
    if Path.cwd().name == "notebooks"
    else Path.cwd().resolve()
)
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

DATA_RAW = PROJECT_ROOT / "data" / "raw"
DATA_PROCESSED = PROJECT_ROOT / "data" / "processed"
FIGURES = PROJECT_ROOT / "reports" / "figures"
RESULTS = PROJECT_ROOT / "reports" / "results"
MODELS = PROJECT_ROOT / "models"

for directory in [DATA_PROCESSED, FIGURES, RESULTS, MODELS]:
    directory.mkdir(parents=True, exist_ok=True)

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

RANDOM_STATE = 42
pd.set_option("display.max_columns", 100)

# %%
from src.data_cleaning import (
    basic_cleaning,
    data_quality_report,
    load_water_quality,
    save_processed,
)
from src.indices_chimiques import add_larson_features

# %% [markdown]
# ## 2. Chargement des deux feuilles

# %%
path = DATA_RAW / "water_quality.xlsx"
mhl = basic_cleaning(load_water_quality(path, "MHLATHUZE"))
luv = basic_cleaning(load_water_quality(path, "LUVUVU"))

print("MHLATHUZE :", mhl.shape)
print("LUVUVU    :", luv.shape)
display(mhl.head())
display(luv.head())
# Out:
# MHLATHUZE : (198, 19)
# LUVUVU    : (84, 23)
#        EC    TDS    pH    HCO3       Cl      SO4      Ca     K      Mg    Na  \
# 0   246.3  177.3  5.08   70.15   27.329    9.881   41.30  5.86    9.49  13.7
# 1  1058.0  711.0  6.22  207.40  145.702   18.918   87.20  8.14   52.60  52.4
# 2   137.0   99.0  6.62   70.15   12.382    2.155    6.98  5.35    3.31  11.3
# 3  1412.0  957.0  6.68  216.55  226.381  135.851   82.30  6.25   44.80  43.3
# 4  1254.0  863.0  6.98  341.60  129.445   68.583  102.00  5.00  107.00  47.2
#
#       NO3      Al     Co      Cu      Fe      Mn      Ni   Zn  Y
# 0   1.597  0.4060  0.000  0.0671  0.0000  0.1120  0.0061  0.0  0
# 1  16.519  0.7200  0.349  0.1004  0.0720  0.2805  0.0914  0.0  2
# 2   6.487  0.0405  0.000  0.0000  0.0000  0.0042  0.0000  0.0  0
# 3   3.200  0.6805  0.265  0.1530  0.0459  0.2085  0.0739  0.0  2
# 4   2.570  0.6815  0.312  0.0508  0.0831  0.2440  0.0560  0.0  2
# ...

# %% [markdown]
# ### Interprétation
#
# Les deux feuilles correspondent à deux sources distinctes. Elles ne doivent pas être confondues avec des mesures provenant de la station d’Al Hoceima.

# %% [markdown]
# ## 3. Contrôle qualité et colonnes disponibles

# %%
print("Colonnes MHLATHUZE :", list(mhl.columns))
print("Colonnes LUVUVU     :", list(luv.columns))

display(data_quality_report(mhl))
display(data_quality_report(luv))
# Out:
# Colonnes MHLATHUZE : ['EC', 'TDS', 'pH', 'HCO3', 'Cl', 'SO4', 'Ca', 'K', 'Mg', 'Na', 'NO3', 'Al', 'Co', 'Cu', 'Fe', 'Mn', 'Ni', 'Zn', 'Y']
# Colonnes LUVUVU     : ['pH', 'EC', 'TDS', 'Na', 'K', 'Ca', 'Mg', 'Cl', 'HCO3', 'SO4', 'NO3', 'F', 'Ag', 'B', 'Cd', 'Co', 'Cr', 'Cu', 'Fe', 'Mn', 'Pb', 'Zn', 'Y']
#         dtype  missing_n  missing_pct  n_unique
# EC    float64          0          0.0       193
# TDS   float64          0          0.0       197
# pH    float64          0          0.0       145
# HCO3  float64          0          0.0       172
# Cl    float64          0          0.0       192
# SO4   float64          0          0.0       184
# Ca    float64          0          0.0       172
# K     float64          0          0.0       159
# Mg    float64          0          0.0       170
# Na    float64          0          0.0       182
# NO3   float64          0          0.0       171
# Al    float64          0          0.0       183
# ...

# %% [markdown]
# ### Interprétation
#
# La colonne `Y` n’est pas exploitée : sa signification n’est pas documentée dans les fichiers fournis. Le projet construit donc sa propre cible d’agressivité à partir d’un indice chimique explicite.

# %% [markdown]
# ## 4. Variables communes retenues

# %%
common = sorted(set(mhl.columns) & set(luv.columns))
chem_candidates = ["pH", "EC", "TDS", "Na", "K", "Ca", "Mg", "Cl", "HCO3", "SO4", "NO3"]
chem = [column for column in chem_candidates if column in common]

print("Colonnes communes :", common)
print("Variables physico-chimiques retenues :", chem)
# Out:
# Colonnes communes : ['Ca', 'Cl', 'Co', 'Cu', 'EC', 'Fe', 'HCO3', 'K', 'Mg', 'Mn', 'NO3', 'Na', 'SO4', 'TDS', 'Y', 'Zn', 'pH']
# Variables physico-chimiques retenues : ['pH', 'EC', 'TDS', 'Na', 'K', 'Ca', 'Mg', 'Cl', 'HCO3', 'SO4', 'NO3']

# %% [markdown]
# ## 5. Calcul de l’indice de Larson

# %% [markdown]
# La formule utilisée est :
#
# \[
# IC = \frac{[Cl^-] + 2[SO_4^{2-}]}{[HCO_3^-]}
# \]
#
# Les trois concentrations sont **d’abord converties de mg/L vers meq/L**. Cette étape est essentielle pour respecter la cohérence de la formule ionique.

# %%
mhl_i = add_larson_features(mhl)
luv_i = add_larson_features(luv)

preview_cols = ["Cl", "SO4", "HCO3", "Larson_index", "Larson_class", "Larson_corrosive"]
display(mhl_i[preview_cols].head())
# Out:
#         Cl      SO4    HCO3  Larson_index Larson_class  Larson_corrosive
# 0   27.329    9.881   70.15      1.028372        Nette                 1
# 1  145.702   18.918  207.40      1.440832        Nette                 1
# 2   12.382    2.155   70.15      0.381833       Faible                 0
# 3  226.381  135.851  216.55      3.393133        Nette                 1
# 4  129.445   68.583  341.60      1.162286        Nette                 1

# %% [markdown]
# ### Interprétation
#
# La variable `Larson_corrosive` vaut 1 lorsque `Larson_index >= 1`. Elle constitue une cible dérivée d’une règle chimique déterministe, et non une étiquette observée indépendamment.

# %% [markdown]
# ## 6. Distribution de Larson et des classes

# %%
for name, data in [("MHLATHUZE", mhl_i), ("LUVUVU", luv_i)]:
    print()
    print(name)
    display(data["Larson_class"].value_counts(dropna=False).to_frame("effectif"))
    display(data["Larson_corrosive"].value_counts(dropna=False).to_frame("effectif"))

    values = data["Larson_index"].replace([np.inf, -np.inf], np.nan).dropna()
    ax = values.plot.hist(bins=30, figsize=(6, 3), title=f"Indice de Larson — {name}")
    ax.axvline(1.0, linestyle="--", label="Seuil corrosif = 1")
    ax.set_xlabel("Indice de Larson")
    ax.legend()
    plt.tight_layout()
    plt.show()
# Out:
# MHLATHUZE
#               effectif
# Larson_class
# Nette              121
# Moyenne             44
# Faible              24
# Légère               7
# Aucune               2
#                   effectif
# Larson_corrosive
# 1                      121
# 0                       77
# LUVUVU
#               effectif
# Larson_class
# Moyenne             35
# Nette               29
# Légère              10
# Faible               9
# Aucune               1
#                   effectif
# Larson_corrosive
# 0                       55
# 1                       29

# %% [markdown]
# ### Interprétation
#
# La distribution de la cible doit être observée avant toute modélisation, car un déséquilibre important peut rendre l’accuracy trompeuse. Les notebooks suivants utilisent donc également F1, PR-AUC et MCC.

# %% [markdown]
# ## 7. Relations entre les variables et Larson

# %%
for name, data in [("MHLATHUZE", mhl_i), ("LUVUVU", luv_i)]:
    columns = [column for column in chem + ["Larson_index"] if column in data.columns]
    print()
    print(name)
    display(
        data[columns]
        .corr(numeric_only=True)[["Larson_index"]]
        .sort_values("Larson_index", ascending=False)
    )
# Out:
# MHLATHUZE
#               Larson_index
# Larson_index      1.000000
# Ca                0.785170
# SO4               0.588934
# Cl                0.540971
# TDS               0.470564
# EC                0.455748
# NO3               0.407623
# Na                0.199040
# Mg                0.108087
# K                 0.022980
# HCO3             -0.045868
# pH               -0.081662
# LUVUVU
#               Larson_index
# Larson_index      1.000000
# Cl                0.627458
# K                 0.551111
# Na                0.539136
# SO4               0.517301
# TDS               0.462472
# EC                0.462472
# pH                0.444071
# Ca                0.293625
# NO3               0.230647
# HCO3              0.164289
# Mg                0.080633

# %% [markdown]
# ### Interprétation
#
# Les relations avec `Cl`, `SO4` et `HCO3` doivent être interprétées avec prudence : ces variables entrent directement dans la formule de Larson. Elles ne constituent donc pas une preuve indépendante que le ML « découvre » la corrosivité.

# %% [markdown]
# ## 8. Langelier : décision méthodologique

# %% [markdown]
# L’indice de Langelier est disponible dans `src/indices_chimiques.py`, mais il **n’est pas calculé ici** si la température nécessaire n’est pas présente dans le jeu de données. Aucune valeur de température arbitraire n’est ajoutée pour obtenir artificiellement un résultat.

# %% [markdown]
# ## 9. Construction du jeu commun pour la modélisation

# %%
columns = chem + ["Larson_index", "Larson_corrosive"]

mhl_common = mhl_i[columns].copy()
mhl_common["source"] = "MHLATHUZE"

luv_common = luv_i[columns].copy()
luv_common["source"] = "LUVUVU"

aggressiveness = (
    pd.concat([mhl_common, luv_common], ignore_index=True)
    .replace([np.inf, -np.inf], np.nan)
    .dropna(subset=["Larson_corrosive"])
    .reset_index(drop=True)
)

aggressiveness["Larson_corrosive"] = aggressiveness["Larson_corrosive"].astype(int)

display(aggressiveness.head())
print("Dimensions du jeu commun :", aggressiveness.shape)
display(aggressiveness["source"].value_counts().to_frame("effectif"))
# Out:
#      pH      EC    TDS    Na     K      Ca      Mg       Cl    HCO3      SO4  \
# 0  5.08   246.3  177.3  13.7  5.86   41.30    9.49   27.329   70.15    9.881
# 1  6.22  1058.0  711.0  52.4  8.14   87.20   52.60  145.702  207.40   18.918
# 2  6.62   137.0   99.0  11.3  5.35    6.98    3.31   12.382   70.15    2.155
# 3  6.68  1412.0  957.0  43.3  6.25   82.30   44.80  226.381  216.55  135.851
# 4  6.98  1254.0  863.0  47.2  5.00  102.00  107.00  129.445  341.60   68.583
#
#       NO3  Larson_index  Larson_corrosive     source
# 0   1.597      1.028372                 1  MHLATHUZE
# 1  16.519      1.440832                 1  MHLATHUZE
# 2   6.487      0.381833                 0  MHLATHUZE
# 3   3.200      3.393133                 1  MHLATHUZE
# 4   2.570      1.162286                 1  MHLATHUZE
# Dimensions du jeu commun : (282, 14)
#            effectif
# source
# MHLATHUZE       198
# LUVUVU           84

# %% [markdown]
# ### Interprétation
#
# La colonne `source` est conservée pour tracer l’origine des observations, mais elle n’est pas utilisée comme variable prédictive dans les expériences principales.

# %% [markdown]
# ## 10. Export

# %%
output_path = DATA_PROCESSED / "aggressiveness_clean.csv"
save_processed(aggressiveness, output_path)
print("Fichier exporté :", output_path)
# Out:
# Fichier exporté : C:\Users\ilias\OneDrive\Documents\PFE\sujet final\desal2_final_corrected\data\processed\aggressiveness_clean.csv

# %% [markdown]
# ## 11. Conclusion du notebook
#
# - Les deux feuilles possèdent un noyau commun de paramètres physico-chimiques.
# - La cible `Y` est volontairement ignorée faute de documentation.
# - Larson est calculé après conversion mg/L → meq/L.
# - `Larson_corrosive` est une cible dérivée de la règle `IC >= 1`.
# - Le notebook 04 comparera **deux expériences** : avec puis sans les variables entrant directement dans la formule de Larson.
